# %% [markdown]
# # 01 — Data Understanding
#
# Declarative overview of the IBM HR Attrition dataset.

# %%
from __future__ import annotations

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from modules.io.datasets import load_ibm_hr_dataset
from modules.eda.profiling import (
    dataset_overview,
    column_profile,
    numeric_profile,
    categorical_profile
)

df = load_ibm_hr_dataset()
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
dataset_overview(df)
# Out:
#             metric  value
# 0             rows   1470
# 1          columns     35
# 2  duplicated_rows      0

# %%
column_profile(df)
# Out:
#                       column   dtype  non_null_count  null_count  null_pct  \
# 0                        Age   int64            1470           0       0.0
# 1                  Attrition  object            1470           0       0.0
# 2             BusinessTravel  object            1470           0       0.0
# 3                  DailyRate   int64            1470           0       0.0
# 4                 Department  object            1470           0       0.0
# 5           DistanceFromHome   int64            1470           0       0.0
# 6                  Education   int64            1470           0       0.0
# 7             EducationField  object            1470           0       0.0
# 8              EmployeeCount   int64            1470           0       0.0
# 9             EmployeeNumber   int64            1470           0       0.0
# 10   EnvironmentSatisfaction   int64            1470           0       0.0
# 11                    Gender  object            1470           0       0.0
# 12                HourlyRate   int64            1470           0       0.0
# 13            JobInvolvement   int64            1470           0       0.0
# 14                  JobLevel   int64            1470           0       0.0
# 15                   JobRole  object            1470           0       0.0
# 16           JobSatisfaction   int64            1470           0       0.0
# 17             MaritalStatus  object            1470           0       0.0
# 18             MonthlyIncome   int64            1470           0       0.0
# 19               MonthlyRate   int64            1470           0       0.0
# 20        NumCompaniesWorked   int64            1470           0       0.0
# 21                    Over18  object            1470           0       0.0
# 22                  OverTime  object            1470           0       0.0
# 23         PercentSalaryHike   int64            1470           0       0.0
# 24         PerformanceRating   int64            1470           0       0.0
# 25  RelationshipSatisfaction   int64            1470           0       0.0
# 26             StandardHours   int64            1470           0       0.0
# 27          StockOptionLevel   int64            1470           0       0.0
# 28         TotalWorkingYears   int64            1470           0       0.0
# 29     TrainingTimesLastYear   int64            1470           0       0.0
# 30           WorkLifeBalance   int64            1470           0       0.0
# 31            YearsAtCompany   int64            1470           0       0.0
# 32        YearsInCurrentRole   int64            1470           0       0.0
# 33   YearsSinceLastPromotion   int64            1470           0       0.0
# 34      YearsWithCurrManager   int64            1470           0       0.0
#
#     unique_count
# 0             43
# 1              2
# 2              3
# 3            886
# 4              3
# 5             29
# 6              5
# 7              6
# 8              1
# 9           1470
# 10             4
# 11             2
# 12            71
# 13             4
# 14             5
# 15             9
# 16             4
# 17             3
# 18          1349
# 19          1427
# 20            10
# 21             1
# 22             2
# 23            15
# 24             2
# 25             4
# 26             1
# 27             4
# 28            40
# 29             7
# 30             4
# 31            37
# 32            19
# 33            16
# 34            18

# %%
numeric_profile(df)
# Out:
#                       column   count          mean          std     min  \
# 0                        Age  1470.0     36.923810     9.135373    18.0
# 1                  DailyRate  1470.0    802.485714   403.509100   102.0
# 2           DistanceFromHome  1470.0      9.192517     8.106864     1.0
# 3                  Education  1470.0      2.912925     1.024165     1.0
# 4              EmployeeCount  1470.0      1.000000     0.000000     1.0
# 5             EmployeeNumber  1470.0   1024.865306   602.024335     1.0
# 6    EnvironmentSatisfaction  1470.0      2.721769     1.093082     1.0
# 7                 HourlyRate  1470.0     65.891156    20.329428    30.0
# 8             JobInvolvement  1470.0      2.729932     0.711561     1.0
# 9                   JobLevel  1470.0      2.063946     1.106940     1.0
# 10           JobSatisfaction  1470.0      2.728571     1.102846     1.0
# 11             MonthlyIncome  1470.0   6502.931293  4707.956783  1009.0
# 12               MonthlyRate  1470.0  14313.103401  7117.786044  2094.0
# 13        NumCompaniesWorked  1470.0      2.693197     2.498009     0.0
# 14         PercentSalaryHike  1470.0     15.209524     3.659938    11.0
# 15         PerformanceRating  1470.0      3.153741     0.360824     3.0
# 16  RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0
# 17             StandardHours  1470.0     80.000000     0.000000    80.0
# 18          StockOptionLevel  1470.0      0.793878     0.852077     0.0
# 19         TotalWorkingYears  1470.0     11.279592     7.780782     0.0
# 20     TrainingTimesLastYear  1470.0      2.799320     1.289271     0.0
# 21           WorkLifeBalance  1470.0      2.761224     0.706476     1.0
# 22            YearsAtCompany  1470.0      7.008163     6.126525     0.0
# 23        YearsInCurrentRole  1470.0      4.229252     3.623137     0.0
# 24   YearsSinceLastPromotion  1470.0      2.187755     3.222430     0.0
# 25      YearsWithCurrManager  1470.0      4.123129     3.568136     0.0
#
#         25%      50%       75%      max
# 0     30.00     36.0     43.00     60.0
# 1    465.00    802.0   1157.00   1499.0
# 2      2.00      7.0     14.00     29.0
# 3      2.00      3.0      4.00      5.0
# 4      1.00      1.0      1.00      1.0
# 5    491.25   1020.5   1555.75   2068.0
# 6      2.00      3.0      4.00      4.0
# 7     48.00     66.0     83.75    100.0
# 8      2.00      3.0      3.00      4.0
# 9      1.00      2.0      3.00      5.0
# 10     2.00      3.0      4.00      4.0
# 11  2911.00   4919.0   8379.00  19999.0
# 12  8047.00  14235.5  20461.50  26999.0
# 13     1.00      2.0      4.00      9.0
# 14    12.00     14.0     18.00     25.0
# 15     3.00      3.0      3.00      4.0
# 16     2.00      3.0      4.00      4.0
# 17    80.00     80.0     80.00     80.0
# 18     0.00      1.0      1.00      3.0
# 19     6.00     10.0     15.00     40.0
# 20     2.00      3.0      3.00      6.0
# 21     2.00      3.0      3.00      4.0
# 22     3.00      5.0      9.00     40.0
# 23     2.00      3.0      7.00     18.0
# 24     0.00      1.0      3.00     15.0
# 25     2.00      3.0      7.00     17.0

# %%
categorical_profile(df)
# Out:
#            column  unique_count               top_value  top_frequency
# 0       Attrition             2                      No           1233
# 1  BusinessTravel             3           Travel_Rarely           1043
# 2      Department             3  Research & Development            961
# 3  EducationField             6           Life Sciences            606
# 4          Gender             2                    Male            882
# 5         JobRole             9         Sales Executive            326
# 6   MaritalStatus             3                 Married            673
# 7          Over18             1                       Y           1470
# 8        OverTime             2                      No           1054
