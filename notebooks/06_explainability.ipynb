# %% [markdown]
# # 06 — Explainability
#
# Declarative SHAP explainability workflow using reusable RetainAI modules.

# %%
from __future__ import annotations

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.retainai.explainability.run_explainability import explain_model

explain_model('logistic_regression')
# Out:
# Explainability artifacts generated for: logistic_regression

# %%
explain_model('random_forest')
# Out:
# Explainability artifacts generated for: random_forest

# %%
explain_model('xgboost')
# Out:
# Explainability artifacts generated for: xgboost
