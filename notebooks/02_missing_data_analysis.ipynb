# %% [markdown]
# # 02 — Missing Data Analysis
#
# Missingness exploration and production-oriented missing data readiness.

# %%
from __future__ import annotations

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2

# %%
from modules.io.datasets import load_ibm_hr_dataset
from modules.eda.missingness import (
    missing_summary,
    has_missing_values,
    missingness_correlation
)

df = load_ibm_hr_dataset()
missing_summary(df)
# Out:
#                       column  missing_count  missing_pct
# 0                        Age              0          0.0
# 1                  Attrition              0          0.0
# 2             BusinessTravel              0          0.0
# 3                  DailyRate              0          0.0
# 4                 Department              0          0.0
# 5           DistanceFromHome              0          0.0
# 6                  Education              0          0.0
# 7             EducationField              0          0.0
# 8              EmployeeCount              0          0.0
# 9             EmployeeNumber              0          0.0
# 10   EnvironmentSatisfaction              0          0.0
# 11                    Gender              0          0.0
# 12                HourlyRate              0          0.0
# 13            JobInvolvement              0          0.0
# 14                  JobLevel              0          0.0
# 15                   JobRole              0          0.0
# 16           JobSatisfaction              0          0.0
# 17             MaritalStatus              0          0.0
# 18             MonthlyIncome              0          0.0
# 19               MonthlyRate              0          0.0
# 20        NumCompaniesWorked              0          0.0
# 21                    Over18              0          0.0
# 22                  OverTime              0          0.0
# 23         PercentSalaryHike              0          0.0
# 24         PerformanceRating              0          0.0
# 25  RelationshipSatisfaction              0          0.0
# 26             StandardHours              0          0.0
# 27          StockOptionLevel              0          0.0
# 28         TotalWorkingYears              0          0.0
# 29     TrainingTimesLastYear              0          0.0
# 30           WorkLifeBalance              0          0.0
# 31            YearsAtCompany              0          0.0
# 32        YearsInCurrentRole              0          0.0
# 33   YearsSinceLastPromotion              0          0.0
# 34      YearsWithCurrManager              0          0.0

# %%
has_missing_values(df)
# Out:
# False

# %%
missingness_correlation(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
