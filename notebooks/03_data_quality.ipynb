# %% [markdown]
# # 03 — Data Quality
#
# Validation-oriented data quality checks.

# %%
from modules.io.datasets import load_ibm_hr_dataset
from modules.eda.quality import (
    constant_columns,
    high_cardinality_columns,
    target_distribution
)

df = load_ibm_hr_dataset()
target_distribution(df)

# %%
constant_columns(df)

# %%
high_cardinality_columns(df)
